# %%
# Python program to read


# Aqui tá como lemos o arquivo data

# json file
import json
 
# # Opening JSON file
f = open('allData.json',)
 
# # returns JSON object as
# # a dictionary
data = json.load(f)
 
# # Iterating through the json
# # list
# print(data)
 
# # Closing file
f.close()
name = 'name'
indicators = 'indicators'


#Aqui tem o mapeamento
mapeamentoTCC = {
    'Eixo Infraestrutura': [
        {
            name: 'escolasUrbanasAlunos_B6',
            indicators: ['SEXO', 'REGIÃO', 'DEPENDÊNCIA ADMINISTRATIVA', 'SÉRIE']
        },
        {
            name: 'escolasUrbanasAlunos_B10',
            indicators: ['DEPENDÊNCIA ADMINISTRATIVA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasAlunos_B11',
            indicators: ['DEPENDÊNCIA ADMINISTRATIVA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_B3',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_B6',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasEscolas_D21A',
            indicators: []
        },
        {
            name: 'escolasUrbanasEscolas_D25A',
            indicators: []
        },
    ],
    'Eixo Conteúdos e Recursos Digitais': [
        
        {
            name: 'escolasUrbanasProfessores_G1',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_G2',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_G2B1',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasEscolas_D10B',
            indicators: []
        },
        {
            name: 'escolasUrbanasEscolas_D22',
            indicators: []
        },
    ],
    'Eixo Utilização de Tecnologia - Aluno': [
        {
            name: 'escolasUrbanasAlunos_E1A',
            indicators: ['SEXO', 'REGIÃO', 'DEPENDÊNCIA ADMINISTRATIVA']
        },
    ],
    'Eixo Utilização de Tecnologia - Professor': [
        {
            name: 'escolasUrbanasProfessores_E2A',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_E3',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_E3A',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_E10C',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_G8A',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_G10',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
    ],
    'Eixo Visão': [
        {
            name: 'escolasUrbanasAlunos_C6',
            indicators: ['SEXO', 'REGIÃO', 'DEPENDÊNCIA ADMINISTRATIVA']
        },
        {
            name: 'escolasUrbanasAlunos_D1',
            indicators: ['SEXO', 'REGIÃO', 'DEPENDÊNCIA ADMINISTRATIVA']
        },
        {
            name: 'escolasUrbanasProfessores_D1A',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_D2',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_D6A',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_D6B',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_F2',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_F3',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_F4',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_F5',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_F6',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_G5',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_G12',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasCoordenadores_C1A1',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasCoordenadores_C5A',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasCoordenadores_C7A',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasCoordenadores_D1',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasCoordenadores_D3',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasCoordenadores_D3A1',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasDiretores_C4A',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasDiretores_D24A1',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasDiretores_E2',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasDiretores_E3',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
    ],
   'Eixo Competência': [

        {
            name: 'escolasUrbanasProfessores_D2A',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasCoordenadores_C3',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasCoordenadores_C3A',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasCoordenadores_C16',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasCoordenadores_C17',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasEscolas_C2A',
            indicators: []
        },
        {
            name: 'escolasUrbanasEscolas_C4A',
            indicators: []
        },
   ],
   'Outros': [
        {
            name: 'escolasUrbanasAlunos_C4C',
            indicators: ['SEXO', 'REGIÃO', 'DEPENDÊNCIA ADMINISTRATIVA']
        },
        {
            name: 'escolasUrbanasAlunos_D3',
            indicators: ['SEXO', 'REGIÃO', 'DEPENDÊNCIA ADMINISTRATIVA']
        },
        {
            name: 'escolasUrbanasProfessores_A1A',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_B1A',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasProfessores_C4A',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasCoordenadores_A1A',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasCoordenadores_B1A',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasDiretores_A1A',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
        {
            name: 'escolasUrbanasDiretores_B7A',
            indicators: ['SEXO', 'FAIXA ETÁRIA', 'REGIÃO']
        },
   ]
}



# const position = selectedTables[key]!.name.split('_');
#       const chosenIndicators = selectedTables[key].indicators;
#       const thisTable = dataset![position[0] as keyof typeof dataset][position[1]];
#       if(!thisTable){
#         console.log('Não possuímos a tabela '+position[1]);
#       } else {
#         activeTables = {
#           table: thisTable,
#           indicators: chosenIndicators
#         }


'''
    Eu quero separar os dados específicos do mapeamento do TCC
    Em outras palavras, meu objetivo é um objeto apenas com os dados do mapeamento para cada ano.
    Ou seja, é um objeto onde, para cada eixo, tem o nome da tabela -> no nome tem os anos -> nos anos tem os dados
'''


#Aqui estamos filtrando os dados para serem apenas os nossos e tratando os dados
#Já funciona, mas tá assim
'''
    newData: {
        'Eixo Infraestrutura': {
            'EscolasUrbanasAlunos_B6':
                '2017': dados de 2017
                '2018': dados de 2018
                '2019': dados de 2019
        }
    }
'''

#A gente quer que fique assim
'''
    newData: {
        'Eixo Infraestrutura': {
            'EscolasUrbanasAlunos': {
                'B6': {
                        '2017': dados de 2017
                        '2018': dados de 2018
                        '2019': dados de 2019
                    }
            }
        }
    }
'''
newData = {}
for axe in mapeamentoTCC:
    thisAxe = {}
    axeTest = {}
    for table in mapeamentoTCC[axe]:
        info = table[name].split('_')
        participants = info[0]
        tableCode = info[1]
        
        #print(table)
        #print(table[name].split('_'))
        
        tableData = {}
        testeTeste = {}
        testeTeste2 = {}
        for year in data:
            #print(year)
            try:
                thisTable = data[year][participants][tableCode]
                #print(thisTable)
                tableData[year] = thisTable
            except KeyError:
                print('nao tem a tabela ', tableCode)
        #print('teyle')
        testeTeste[tableCode] = tableData
        testeTeste2[participants] = []
        testeTeste2[participants].append(testeTeste)
        if participants not in thisAxe.keys():
            thisAxe[participants] = []
        thisAxe[participants].append(testeTeste)
        #teste = {}

#         thisAxe[table[name]] = tableData
    newData[axe] = thisAxe
    

json_object = json.dumps(newData, indent = 4).encode('utf8')
  
# Writing to sample.json
with open("sample2.json", "w") as outfile:
    outfile.write(json_object.decode())
    
# print(newData['Eixo Infraestrutura']['escolasUrbanasAlunos'][1].keys())
# print(newData['Eixo Infraestrutura'])
# for year in data:
# #     print(data[year])
#     print('============')
#     print(data[year]['escolasUrbanasAlunos']['A1'])
# Out:
# nao tem a tabela  D21A
# nao tem a tabela  G2B1
# nao tem a tabela  G5
# nao tem a tabela  C1A1
# nao tem a tabela  C5A
# nao tem a tabela  D3A1
# nao tem a tabela  C4A
# nao tem a tabela  D24A1
# nao tem a tabela  D2A
# nao tem a tabela  C16
# nao tem a tabela  C17
# nao tem a tabela  C2A
# nao tem a tabela  C4A
# nao tem a tabela  A1A
# nao tem a tabela  A1A
# nao tem a tabela  A1A
# nao tem a tabela  A1A
# nao tem a tabela  A1A
# nao tem a tabela  A1A
